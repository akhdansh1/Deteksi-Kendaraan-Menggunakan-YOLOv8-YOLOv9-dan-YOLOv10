# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0dd09f8a-8049-4d3c-941c-3a73631b1598" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0dd09f8a-8049-4d3c-941c-3a73631b1598">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

with zipfile.ZipFile("Vehicle Detection.v2i.yolov12.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/vehicle-detection")

# %%
from ultralytics import YOLO

model = YOLO('yolov10n.pt')  # Gunakan 'yolov10s.pt', 'yolov10m.pt', dst. jika ingin model lebih besar

model.train(
    data="/content/vehicle-detection/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    name="yolov10-vehicle"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.59M/5.59M [00:00<00:00, 64.0MB/s]
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load model hasil training
model = YOLO('/content/runs/detect/yolov10-vehicle/weights/best.pt')

# Evaluasi pada validation set
metrics = model.val(data='/content/vehicle-detection/data.yaml')
# Out:
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv10n summary (fused): 102 layers, 2,265,948 parameters, 0 gradients, 6.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1797.4±686.6 MB/s, size: 81.0 KB)
# val: Scanning /content/vehicle-detection/valid/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:03<00:00,  1.97it/s]
#                    all        100       1107      0.895      0.823      0.904      0.732
#                    bus         35         37      0.985      0.892      0.923      0.866
#                    car         92        366      0.897      0.857      0.947      0.771
#              motorbike         90        611      0.854      0.661      0.814      0.494
#                  truck         62         93      0.843      0.882      0.932      0.795
# ...

# %%
# Ambil daftar metrik per kelas
precisions = metrics.box.p
recalls = metrics.box.r
f1_scores = metrics.box.f1
names = model.names  # label nama kelas

# Tampilkan per kelas
for i, name in names.items():
    print(f"{name}: Precision={precisions[i]:.2f}, Recall={recalls[i]:.2f}, F1-score={f1_scores[i]:.2f}")

# Tampilkan rata-rata
print("\n--- Mean Metrics ---")
print(f"Mean Precision: {sum(precisions)/len(precisions):.2f}")
print(f"Mean Recall   : {sum(recalls)/len(recalls):.2f}")
print(f"Mean F1 Score : {sum(f1_scores)/len(f1_scores):.2f}")
# Out:
# bus: Precision=0.98, Recall=0.89, F1-score=0.94
# car: Precision=0.90, Recall=0.86, F1-score=0.88
# motorbike: Precision=0.85, Recall=0.66, F1-score=0.75
# truck: Precision=0.84, Recall=0.88, F1-score=0.86
#
# --- Mean Metrics ---
# Mean Precision: 0.89
# Mean Recall   : 0.82
# Mean F1 Score : 0.85

# %%
from IPython.display import Image
Image(filename='/content/runs/detect/yolov10-vehicle/results.png')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/runs /content/drive/MyDrive/

# %%
from google.colab import files
uploaded = files.upload()  # akan muncul tombol upload, pilih file gambarnya
# Out:
#      <input type="file" id="files-13d3ab72-b152-4520-be5c-5e07f5f950c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-13d3ab72-b152-4520-be5c-5e07f5f950c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/yolov10-vehicle/weights/best.pt")

# Contoh prediksi 1 gambar
results = model.predict(source="image_1_127_jpg.rf.00427966330d7aa33b0fc23041eef76d.jpg", save=True)
# Out:
# image 1/1 /content/image_1_127_jpg.rf.00427966330d7aa33b0fc23041eef76d.jpg: 640x640 3 cars, 17 motorbikes, 10.7ms
# Speed: 3.0ms preprocess, 10.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# !cp -r /content/runs /content/drive/MyDrive/

# %%
from IPython.display import Image, display

image_path = '/content/drive/MyDrive/runs/detect/predict/image_1_127_jpg.rf.00427966330d7aa33b0fc23041eef76d.jpg'
display(Image(filename=image_path))

# %%
result = model.predict('image_1_127_jpg.rf.00427966330d7aa33b0fc23041eef76d.jpg')
# Out:
# image 1/1 /content/image_1_127_jpg.rf.00427966330d7aa33b0fc23041eef76d.jpg: 640x640 3 cars, 17 motorbikes, 14.3ms
# Speed: 2.4ms preprocess, 14.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Buka gambar asli
img = Image.open('image_1_127_jpg.rf.00427966330d7aa33b0fc23041eef76d.jpg')
img_flip = img.transpose(Image.FLIP_LEFT_RIGHT)
img_rot = img.rotate(15)

# Tampilkan semua gambar
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(img)
plt.title("Asli")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(img_flip)
plt.title("Flip")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(img_rot)
plt.title("Rotate 15°")
plt.axis('off')

plt.show()

# Konversi ke array jika perlu
img_np = np.array(img)
img_flip_np = np.array(img_flip)
img_rot_np = np.array(img_rot)

# Lakukan prediksi
res1 = model.predict(source=img_np)
res2 = model.predict(source=img_flip_np)
res3 = model.predict(source=img_rot_np)

# Kombinasikan hasil prediksi di sini sesuai kebutuhan
# Misalnya: voting klasifikasi, gabung bounding box, dst
# Out:
# 0: 640x640 3 cars, 16 motorbikes, 18.1ms
# Speed: 5.5ms preprocess, 18.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 2 cars, 18 motorbikes, 1 truck, 11.5ms
# Speed: 5.3ms preprocess, 11.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 7 motorbikes, 3 trucks, 13.4ms
# Speed: 2.5ms preprocess, 13.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
